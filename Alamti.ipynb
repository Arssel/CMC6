# %%
import geopy
from geopy.geocoders import Nominatim, ArcGIS, GeocodeFarm, GeoNames, OpenCage, OpenMapQuest, Pelias, Photon
import plotly.graph_objects as go

import numpy as np
import pandas as pd
import time
import requests
import pickle
from tqdm import tqdm
from matplotlib import pyplot as plt

from bs4 import BeautifulSoup

import os
import re

import osrm


import seaborn as sns
from sklearn.neighbors import KernelDensity

import torch

# %% [markdown]
# ## Загрузка координат и расстояний

# %%
app = Nominatim(user_agent="my-application")

# %%
file_list = os.listdir('./data/Almaty_Success/')

# %%
columns = list(df.columns)
df_full = pd.DataFrame(data=None, columns=columns + ['Date'])

# %%
for i in range(len(file_list)):
    df = pd.read_csv('./data/Almaty_Success/' + file_list[i], delimiter='\t')
    df['Date'] = file_list[i]
    df_full = pd.concat((df_full, df), ignore_index=True)

# %%
df_full = df_full.dropna(subset=['DeliveryAddress']).reset_index(drop=True)

# %%
df_full.to_csv('./data/all_files.csv', sep='|')

# %%
df_full = pd.read_csv('./data/all_files.csv', delimiter='|')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning:
#
# Columns (5,8) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
unique_addresses = df_full['DeliveryAddress'].drop_duplicates().reset_index(drop=True)

# %%
s = 0
first_address_list = []
for i in tqdm(range(len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            first_address_list.append(app.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#  19%|██████████████                                                              | 1827/9854 [16:18<1:06:11,  2.02it/s]
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# ...

# %%
ag = ArcGIS(token_lifetime=1)

# %%
s = 0
for i in tqdm(range(1827, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(1)
            first_address_list.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#   1%|▉                                                                             | 95/8027 [02:57<3:38:48,  1.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-94be4f3a8250> in <module>
#       8         try:
# ----> 9             time.sleep(1)
#      10             first_address_list.append(ag.geocode(address))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-86-94be4f3a8250> in <module>
#      11             flag = False
#      12         except KeyboardInterrupt:
# ---> 13             print(1/0)
#      14         except:
#      15             time.sleep(1)
#
# ZeroDivisionError: division by zero

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(1.2)
            first_address_list.append(app.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#  10%|████████                                                                     | 827/7922 [20:07<2:54:20,  1.47s/it]
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-ef1649a1f111> in <module>
#       9             time.sleep(1.2)
# ---> 10             first_address_list.append(app.geocode(address))
#      11             flag = False
#
# ...

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10 + 827 + 5, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(2)
            first_address_list.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#   3%|█▉                                                                           | 184/7090 [08:22<5:06:30,  2.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-f7f1e2bec4df> in <module>
#       8         try:
# ----> 9             time.sleep(2)
#      10             first_address_list.append(ag.geocode(address))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-92-f7f1e2bec4df> in <module>
#      11             flag = False
#      12         except KeyboardInterrupt:
# ---> 13             print(1/0)
#      14         except:
#      15             time.sleep(1)
#
# ZeroDivisionError: division by zero

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10 + 827 + 5 + 184, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(2)
            first_address_list.append(app.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#  17%|█████████████▏                                                              | 1204/6906 [45:57<3:34:33,  2.26s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-9029cede86b3> in <module>
#       8         try:
# ----> 9             time.sleep(2)
#      10             first_address_list.append(app.geocode(address))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-93-9029cede86b3> in <module>
#      11             flag = False
#      12         except KeyboardInterrupt:
# ---> 13             print(1/0)
#      14         except:
#      15             time.sleep(1)
#
# ZeroDivisionError: division by zero

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10 + 827 + 5 + 184 + 1204, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(2)
            first_address_list.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#  12%|█████████▍                                                                   | 701/5702 [37:04<3:50:17,  2.76s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-543e6a03cea8> in <module>
#       9             time.sleep(2)
# ---> 10             first_address_list.append(ag.geocode(address))
#      11             flag = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in geocode(self, query, exactly_one, timeout, out_fields)
#     194         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
# --> 195         response = self._call_geocoder(url, timeout=timeout)
#     196
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
# ...

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10 + 827 + 5 + 184 + 1204 + 701, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(2)
            first_address_list.append(app.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#  60%|████████████████████████████████████████████▍                             | 3007/5001 [1:55:29<1:15:24,  2.27s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-67962c3db142> in <module>
#       8         try:
# ----> 9             time.sleep(2)
#      10             first_address_list.append(app.geocode(address))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-97-67962c3db142> in <module>
#      11             flag = False
#      12         except KeyboardInterrupt:
# ---> 13             print(1/0)
#      14         except:
#      15             time.sleep(1)
#
# ZeroDivisionError: division by zero

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10 + 827 + 5 + 184 + 1204 + 701 + 3007, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(2)
            first_address_list.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)

# %%
s = 0
for i in tqdm(range(1827 + 95 + 10 + 827 + 5 + 184 + 1204 + 701 + 3007 + 831, len(unique_addresses)), position=0, leave=True):
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(2)
            first_address_list.append(app.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1163/1163 [44:20<00:00,  2.29s/it]

# %%
#pd.Series(list(map(lambda x: list(x)[1] if x is not None else x, first_address_list))).to_csv('ready_coord.csv', sep='|')
#pd.Series(list(map(lambda x: list(x)[0] if x is not None else x, first_address_list))).to_csv('ready_addr.csv', sep='|')

# %%
df_full = pd.read_csv('./data/all_files.csv', delimiter='|')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning:
#
# Columns (5,8) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
unique_addresses = df_full['DeliveryAddress'].drop_duplicates().reset_index(drop=True)

# %%
addresses = pd.read_csv('ready_addr.csv', delimiter='|').drop('Unnamed: 0', axis=1)
coords = pd.read_csv('ready_coord.csv', delimiter='|').drop('Unnamed: 0', axis=1)

# %%
s = 0
new_addresses = []
for i in tqdm(range(len(unique_addresses)), position=0, leave=True):
    if not addresses.iloc[i, :].isna().item():
        new_addresses.append((addresses.iloc[i, :].item(), coords.iloc[i, :].item()))
        continue
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    flag = True
    while flag:
        try:
            time.sleep(3)
            new_addresses.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#  19%|██████████████                                                              | 1827/9854 [35:30<5:18:27,  2.38s/it]
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# ...

# %%
ag = ArcGIS(timeout=60)

# %%
s = 0
for i in tqdm(range(1922, len(unique_addresses)), position=0, leave=True):
    if not addresses.iloc[i, :].isna().item():
        new_addresses.append((addresses.iloc[i, :].item(), coords.iloc[i, :].item()))
        continue
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    print(address)
    flag = True
    while flag:
        try:
            time.sleep(3)
            new_addresses.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#   0%|                                                                                         | 0/7932 [00:00<?, ?it/s]
# Алматы, Каменское плато, садовое товарищество Родник, 11
#   0%|                                                                              | 1/7932 [00:06<14:34:39,  6.62s/it]
# Алматы, Микрорайон Шапагат, ул бердыкулова, 12
#   0%|                                                                              | 2/7932 [00:10<12:43:00,  5.77s/it]
# Алматы, Поселок боралдай, черемушки , 39
#   0%|                                                                               | 8/7932 [00:14<9:17:44,  4.22s/it]
# Алматы, 13 военный городок, 3
#   0%|                                                                              | 10/7932 [00:17<7:42:22,  3.50s/it]
# Алматы, микрорайон Мамыр-4, 1
#   0%|                                                                              | 11/7932 [00:21<7:47:49,  3.54s/it]
# ...

# %%
s = 0
for i in tqdm(range(8878, len(unique_addresses)), position=0, leave=True):
    if not addresses.iloc[i, :].isna().item():
        new_addresses.append((addresses.iloc[i, :].item(), coords.iloc[i, :].item()))
        continue
    address = unique_addresses[i]
    if 'Алматы' not in unique_addresses[i]:
        address = 'Алматы, ' + address
    print(address)
    flag = True
    while flag:
        try:
            time.sleep(3)
            new_addresses.append(ag.geocode(address))
            flag = False
        except KeyboardInterrupt:
            print(1/0)
        except:
            time.sleep(1)
# Out:
#   0%|                                                                                          | 0/976 [00:00<?, ?it/s]
# Алматы, улица Брусиловского , 159блок1 , 28
#   0%|                                                                                  | 1/976 [00:03<58:40,  3.61s/it]
# Алматы, микрорайон Орбита-1 , 6, Papa Jons
#   0%|▏                                                                                 | 2/976 [00:07<59:33,  3.67s/it]
# Алматы, Абая 10в, Дом, Офис
#   0%|▎                                                                                 | 3/976 [00:11<59:12,  3.65s/it]
# Алматы, Кыргауылды, Карасайский район,  село Кыргауылды, улица Инкарбекова 53 г, Инкарбекова 53 г
#   1%|▍                                                                                 | 5/976 [00:14<50:12,  3.10s/it]
# Алматы, Жадаукок, 26д
#   1%|▌                                                                                 | 6/976 [00:18<52:36,  3.25s/it]
# ...

# %%
new_addresses[14]
# Out:
# ('57, улица Панфилова, Алмалинский район, Алматы, 05004, Қазақстан',
#  '(43.26615445, 76.94319858202073)')

# %%
(new_addresses[15].address, '(' + str(new_addresses[15].latitude) + ', ' + str(new_addresses[15].longitude) + ')')
# Out:
# ('Теректы 60, Алматы', '(43.24561373397538, 76.78699932284205)')

# %%
mapped_addresses = []
for i in range(len(new_addresses)):
    if type(new_addresses[i]) == geopy.location.Location:
        mapped_addresses.append((new_addresses[i].address,
                                 '(' + str(new_addresses[i].latitude) + ', ' + str(new_addresses[i].longitude) + ')'))
    else:
        mapped_addresses.append(new_addresses[i])

# %%
df3 = pd.Series(list(map(lambda x: list(x)[1] if x is not None else x, mapped_addresses)))

# %% [markdown]
# ## Расстояния

# %%
import osrm

# %%
with open('ready_addr_final.pkl', 'rb') as f:
    df_addr = pickle.load(f)

# %%
with open('ready_coord_final.pkl', 'rb') as f:
    df_coord = pickle.load(f)

# %%
ag.geocode('Алматы 1, Вокзал 1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f5f87b46be1b> in <module>
# ----> 1 ag.geocode('Алматы 1, Вокзал 1')
#
# NameError: name 'ag' is not defined

# %%
df_coord[5425] = '(43.35794998489226, 76.86101997125007)'

# %%
df_addr[5425] = 'Вокзал көшесі 1, Боралдай, Іле ауданы, Алматы облысы'

# %%
failed_addresses = list(filter(
    lambda x: x[1][0] > 44, 
    zip(np.arange(len(df_coord)), 
        map(lambda x: (float(x.split(', ')[0][1:]), float(x.split(', ')[1][:-1])), df_coord.to_list()))))

# %%
failed_addresses_2 = list(filter(
    lambda x: x[1][0] < 43, 
    zip(np.arange(len(df_coord)), map(lambda x: (float(x.split(', ')[0][1:]), float(x.split(', ')[1][:-1])), df_coord.to_list()))))

# %%
failed_addresses_3 = list(filter(
    lambda x: x[1][1] < 75, 
    zip(np.arange(len(df_coord)), 
        map(lambda x: (float(x.split(', ')[0][1:]), float(x.split(', ')[1][:-1])), df_coord.to_list()))))

# %%
correct_coord = pd.read_excel('failed addresses.xlsx', header=None)

# %%
df_coord[correct_coord.loc[:, 0]] = correct_coord.loc[:, 1]

# %%
from matplotlib import pyplot as plt

# %%
coords = np.array(list(map(lambda x: (float(x.split(', ')[0][1:]), float(x.split(', ')[1][:-1])), df_coord.drop_duplicates().to_list())))

# %%
filtered_coords = coords[(76.7 < coords[:, 1]) & (coords[:, 1] < 77) 
                         & (43.20 < coords[:, 0]) & (coords[:, 0] < 43.30 ), :]

# %%
fig = plt.figure(figsize=(8, 8))
plt.grid()
plt.scatter(filtered_coords[:, 1], filtered_coords[:, 0], s=0.5)

# %%
coords = coords[:, ::-1]

# %%
osrm.RequestConfig
# Out:
# http://localhost:5000/*/v1/driving

# %%
df_add_coord = pd.DataFrame(unique_addresses).join(pd.DataFrame(df_coord, columns=['coords']))

# %%
df_add_coord
# Out:
#                          DeliveryAddress  \
# 0     Алматы, микрорайон Айнабулак-2, 81
# 1         Алматы, Ужет ,ул Токатаева, 58
# 2         Алматы, микрорайон Калкаман, 7
# 3           Алматы, улица Гагарина, 154
# 4            Алматы, улица Кунаева, 119
# ...                                  ...
# 9849             бульвар Бухар Жырау, 61
# 9850                Сулейменова, 24а, 51
# 9851               улица Бультрикова , 6
# 9852               улица Кулымбетова , 3
# 9853                   проспект Абая, 44
#
#                                        coords
# 0                   (43.31748695, 76.9165275)
# 1                    (43.3175298, 76.8919455)
# 2     (43.232188550000004, 76.79991440374957)
# 3                      (43.402316, 77.009479)
# 4                    (43.2524397, 76.9502925)
# ...                                       ...
# 9849         (43.23124865, 76.90814087759435)
# 9850   (43.25892028957748, 76.83470049114544)
# 9851           (43.1989399, 76.8980945010671)
# ...

# %% [markdown]
# ## Соединение с оригинальным датасетом

# %%
df_full = df_full.drop('Unnamed: 0', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-15c0223a61a4> in <module>
# ----> 1 df_full = df_full.drop('Unnamed: 0', axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df_full = df_full.merge(df_add_coord, how='left', on='DeliveryAddress')

# %%
df_cut = df_full.drop(['VehicleType', 'Comments', 'PickupName', 
              'PickupPhone', 'DeliveryPhone', 'DeliveryName', 
              'LoadingTime', 'PricePerStop', 'CustomerPays',
              'UnloadingTime', 'Volume'], axis=1).drop_duplicates()

# %%
df_order_date_dict = df_cut[['OrderID', 'Date']].drop_duplicates(subset='OrderID')

# %%
df_cut_cut = df_cut.drop('Date', axis=1).drop_duplicates().merge(df_order_date_dict, on='OrderID')

# %%
distr = df_cut_cut['Date'].value_counts()

# %%
with open('full_df.pkl', 'wb') as f:
    pickle.dump(df_cut_cut, f)

# %% [markdown]
# ## Матрица расстояний

# %%
with open('full_df.pkl', 'rb') as f:
    df_cut = pickle.load(f)

# %%
distr = df_cut['Date'].value_counts()

# %%
import seaborn as sns
from sklearn.neighbors import KernelDensity

# %%
coords = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[:, 8].drop_duplicates().to_list())))

# %%
kd = KernelDensity(bandwidth=0.02, kernel='tophat')

kd.fit(coords,)

sample = kd.sample(10000)

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(coords[:, 0], coords[:, 1], s=0.4)
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.savefig('almati.png')

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(filtered_coords[:, 0], filtered_coords[:, 1], s=0.5)
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.savefig('almati_sized.png')

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(sample[:, 0], sample[:, 1], s=0.5)
plt.scatter(coords[:, 0], coords[:, 1], s=0.5)
plt.legend(['sample', 'true'])
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.savefig('tophat_002_with_sample.png')

# %%
filtered_coords = coords[(76.7 < coords[:, 0]) & (coords[:, 0] < 77) 
                         & (43.20 < coords[:, 1]) & (coords[:, 1] < 43.30 ), :]

# %%
filtered_sample = sample[(76.7 < sample[:, 0]) & (sample[:, 0] < 77) 
                         & (43.20 < sample[:, 1]) & (sample[:, 1] < 43.30 ), :]

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(filtered_sample[:, 0], filtered_sample[:, 1], s=0.5)
plt.scatter(filtered_coords[:, 0], filtered_coords[:, 1], s=0.5)
plt.legend(['sample', 'true'])
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.savefig('tophat_002_sized_with_sample.png')

# %%
distr.mean()
# Out:
# 111.55102040816327

# %%
plt.figure(figsize = (8,8))
snsplot = sns.kdeplot(distr[distr <= 200], shade=True, cut=0, clip=(0, 200))
fig = snsplot.get_figure()
plt.savefig('cont_density.png')

# %%
kd = KernelDensity(bandwidth=0.01, kernel='gaussian')

# %%
kd.fit(distr[distr <= 200].to_numpy().reshape(-1, 1))
# Out:
# KernelDensity(algorithm='auto', atol=0, bandwidth=0.01, breadth_first=True,
#               kernel='gaussian', leaf_size=40, metric='euclidean',
#               metric_params=None, rtol=0)

# %%
s = kd.sample(100)

# %%
sns.kdeplot(s.reshape(-1))

# %%
plt.figure(figsize = (8,8))
plt.hist(distr, bins='stone')
plt.savefig('discrete_density.png')

# %%
r = osrm.table(sample)

# %%
with open('loc_distance.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %%
r = osrm.table(coords)

# %%
with open('loc_distance_real.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %%
depot = np.array([[76.988360, 43.295950]])

# %%
dataset_size = 1
problem_size = 10000
list_id = ['name' + str(i) for i in range(problem_size + 2)]

# %%
# %%time

dataset = []
for i in range(dataset_size):
    data = {}
    rand_ind = np.random.choice(df_cut.shape[0], size=(problem_size), replace=False)
    data['demands'] = np.concatenate((np.array([0]), df_cut.iloc[rand_ind, 0].to_numpy().squeeze(), np.array([0])))
    data['coords'] = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[rand_ind, 7].to_list())))
    data['coords'] = np.concatenate((depot, data['coords'], depot))
    data['num_vehicles'] = 12
    data['vehicle_capacities'] = [700]*data['num_vehicles']
    t = np.random.choice([0, 120, 240, 360, 480, 600], size=(problem_size + 2))
    t1 = t + 120
    data['time_windows'] = np.concatenate((t.reshape(-1, 1), t1.reshape(-1, 1)), axis=1)
    data['time_windows'][[0, problem_size+1], 0] = 0
    data['time_windows'][0, 1] = 150
    data['time_windows'][ problem_size+1, 1] = 720
    r = osrm.table(data['coords'], ids_origin=list_id, output='dataframe')
    lon = (data['coords'][:, 0] - data['coords'][:, 0].min()).reshape(-1, 1)
    lat = (data['coords'][:, 1] - data['coords'][:, 1].min()).reshape(-1, 1)
    data['coords'] = np.concatenate((lon/lon.max(), lat/lat.max()), axis=1)
    data['time_matrix'] = (r[0]/60).to_numpy()
    data['time_matrix'] += 15
    data['time_matrix'] -= np.diag([15]*(problem_size+2))
    data['time_matrix'][:, -1] = 0
    data['time_matrix'][-1, :] = 0
    dataset.append(data)
# Out:
# Wall time: 5min 1s

# %%
with open('cvrp_tw_dataset.pkl', 'wb') as f:
    pickle.dump(dataset, f)

# %%
coords_list = []
for date in df_cut['Date'].unique():
    coords_list.append(np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut[df_cut['Date'] == date]['coords'].to_list()))))

# %%
coords_with_depot = list(map(lambda x: np.concatenate((depot, x)), coords_list))

# %%
distances_list = []

# %%
for coords in coords_list:
    n = len(coords)
    list_id = ['name' + str(i) for i in range(n)]
    if n > 1:
        r = osrm.table(coords,ids_origin=list_id, output='dataframe')
        distances_list.append(r[0]/60)
    else:
        r = None
        distances_list.append(r)

# %%
with open('distances_list.pkl', 'wb') as f:
    pickle.dump(distances_list, f)

# %%
with open('distances_list.pkl', 'rb') as f:
    distances_list = pickle.load(f)

# %%
d_list = []
for d in distances_list:
    if d is None:
        continue
    d[d>0] += 15
    d_list.append(d)

# %% [markdown]
# ## Обрезанный датасет №1

# %%
with open('full_df.pkl', 'rb') as f:
    df_cut = pickle.load(f)

# %%
coords = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[:, 8].drop_duplicates().to_list())))

# %%
filtered_coords = coords[(76.7 < coords[:, 0]) & (coords[:, 0] < 77.2) 
                         & (43.15 < coords[:, 1]) & (coords[:, 1] < 43.45 ), :]

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
#plt.scatter(filtered_sample[:, 0], filtered_sample[:, 1], s=0.5)
plt.scatter(filtered_coords[:, 0], filtered_coords[:, 1], s=0.5)
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.savefig('almati_no_outliers.png')
#plt.legend(['true', 'sample'])

# %%
kd = KernelDensity(bandwidth=0.02, kernel='tophat')

kd.fit(filtered_coords,)

sample = kd.sample(10000)

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(sample[:, 0], sample[:, 1], s=0.5)
plt.scatter(filtered_coords[:, 0], filtered_coords[:, 1], s=0.5)
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.legend(['sample', 'true'])
plt.savefig('tophat_002_no_outliers_with_sample.png')

# %%
r = osrm.table(sample)

# %%
with open('loc_distance_close.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %%
r1 = torch.tensor(r[0][:50, :50]/60)

# %%
r2 = r1.expand(2, 50, 50)

# %%
np.percentile(r2/60, np.arange(5, 101, 5), axis=2).transpose(1, 2, 0).shape
# Out:
# (2, 50, 20)

# %%
r[0][0, :]/60
# Out:
# array([ 0.        , 26.94666667,  9.68333333, ..., 14.51166667,
#        13.79      , 12.75166667])

# %%
np.percentile(r[0]/60, np.arange(10, 101, 5), axis=1).T[5000]/720
# Out:
# array([0.00816181, 0.00941169, 0.01058333, 0.01148553, 0.01260278,
#        0.01364039, 0.01471528, 0.01570266, 0.01668866, 0.017839  ,
#        0.01907731, 0.02012512, 0.02122292, 0.02253762, 0.02399537,
#        0.02584491, 0.02863449, 0.03395671, 0.08457176])

# %%
np.percentile(r[0]/60, np.arange(10, 101, 5), axis=1).T[500]/720
# Out:
# array([0.00756204, 0.00916528, 0.01025648, 0.01138426, 0.01251319,
#        0.01356019, 0.01445278, 0.01538681, 0.01644097, 0.01751134,
#        0.0185    , 0.01936343, 0.02016898, 0.02117535, 0.02221343,
#        0.02345208, 0.02554907, 0.02845625, 0.07600231])

# %%
np.percentile(r[0]/60, np.arange(10, 101, 5), axis=1).T[0]/720
# Out:
# array([0.00668981, 0.00782338, 0.00880787, 0.00977431, 0.01083495,
#        0.01174769, 0.0126713 , 0.01378137, 0.01499769, 0.01612604,
#        0.01745602, 0.01906019, 0.02049838, 0.0219919 , 0.02371852,
#        0.02564884, 0.02886991, 0.03428704, 0.08115278])

# %%
r[0]/60
# Out:
# array([[ 0.        , 26.94666667,  9.68333333, ..., 14.51166667,
#         13.79      , 12.75166667],
#        [26.64      ,  0.        , 24.56      , ..., 29.86333333,
#         26.05333333, 25.24833333],
#        [10.84666667, 24.99      ,  0.        , ..., 22.31      ,
#          6.11833333,  4.19333333],
#        ...,
#        [15.61666667, 31.03      , 24.31333333, ...,  0.        ,
#         27.30166667, 26.26333333],
#        [14.03166667, 25.        ,  6.33833333, ..., 25.495     ,
#          0.        ,  3.82333333],
#        [13.44      , 24.40833333,  5.18      , ..., 24.90333333,
#          2.43666667,  0.        ]])

# %% [markdown]
# ## Датасет с большим числом точек по округам

# %%
with open('full_df.pkl', 'rb') as f:
    df_cut = pickle.load(f)

# %%
coords = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[:, 8].drop_duplicates().to_list())))

# %%
kd = KernelDensity(bandwidth=0.025, kernel='tophat')

kd.fit(coords,)

sample = kd.sample(10000)

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(sample[:, 0], sample[:, 1], s=0.5)
plt.scatter(coords[:, 0], coords[:, 1], s=0.5)
plt.legend(['sample', 'true'])

# %%
filtered_coords = coords[((76.7 >= coords[:, 0]) | (coords[:, 0] >= 77.2) )
                         | ((43.15 >= coords[:, 1]) | (coords[:, 1] >= 43.45 )), :]

# %%
additional_points = 20

# %%
all_new_coords = []
for i in range(filtered_coords.shape[0]):
    theta = 2*np.pi*np.random.rand(additional_points)
    r = 0.025*np.sqrt(np.random.rand(additional_points))
    new_coords = (filtered_coords[i, :].reshape(-1, 1) - np.array((r*np.cos(theta), r*np.sin(theta)))).T
    all_new_coords.append(new_coords)
all_new_coords = np.vstack(all_new_coords)

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
#plt.scatter(sample[:, 0], sample[:, 1], s=0.5)
plt.scatter(filtered_coords[:, 0], filtered_coords[:, 1], s=0.5)
plt.scatter(all_new_coords[:, 0], all_new_coords[:, 1], s=0.5)
plt.legend(['sample', 'true'])

# %%
sample_full = np.vstack((sample, all_new_coords))

# %%
fig = plt.figure(figsize=(8,8))
plt.grid()
plt.scatter(sample_full[:, 0], sample_full[:, 1], s=0.5)
plt.scatter(coords[:, 0], coords[:, 1], s=0.5)
plt.legend(['sample', 'true'])
plt.ylabel('latitude', fontsize=15)
plt.xlabel('longitude', fontsize=15)
plt.savefig('tophat_002_with_islands_with_sample.png')

# %%
r = osrm.table(sample_full)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-57-e820ab6db61a> in <module>
# ----> 1 r = osrm.table(sample_full)
#
# C:\ProgramData\Anaconda3\lib\site-packages\osrm\core.py in table(coords_src, coords_dest, ids_origin, ids_dest, output, minutes, annotations, url_config, send_as_polyline)
#     347         req.add_header("Authorization", url_config.auth)
#     348     rep = urlopen(req)
# --> 349     parsed_json = json.loads(rep.read().decode('utf-8'))
#     350
#     351     if "code" not in parsed_json or "Ok" not in parsed_json["code"]:
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
with open('loc_distance_islands.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# ## острова с депо

# %%
with open('loc_distance_islands.pkl', 'rb') as f:
    r = pickle.load(f)

# %%
new_coords = np.vstack((depot, r[1]))

# %%
r = osrm.table(new_coords)

# %%
with open('loc_distance_islands_with_depot.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# ## Новый трейн размера 10к

# %%
with open('full_df.pkl', 'rb') as f:
    df_cut = pickle.load(f)

# %%
coords = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[:, 8].drop_duplicates().to_list())))

# %%
kd = KernelDensity(bandwidth=0.025, kernel='tophat')

kd.fit(coords,)

sample = kd.sample(10000)

# %%
r = osrm.table(sample)

# %%
with open('train_10k.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# ## Новый трейн 20к

# %%
kd = KernelDensity(bandwidth=0.025, kernel='tophat')

kd.fit(coords,)

sample = kd.sample(20000)

# %%
r = osrm.table(sample[:10000])

# %%
with open('train_20k_11.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %%
import gc

# %%
r = osrm.table(sample[10000:])

# %%
with open('train_20k_22.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %%
del r

# %%
gc.collect()
# Out:
# 105

# %%
r = osrm.table(coords_src=sample[:10000].tolist(), coords_dest=sample[10000:].tolist())

# %%
with open('train_20k_12.pkl', 'wb') as f:
    pickle.dump((r[0]/60), f)

# %%
del r

# %%
gc.collect()
# Out:
# 60

# %%
r = osrm.table(sample[10000:].tolist(), sample[:10000].tolist())

# %%
with open('train_20k_21.pkl', 'wb') as f:
    pickle.dump((r[0]/60), f)

# %%
del r

# %%
gc.collect()
# Out:
# 60

# %% [markdown]
# ## Валидация

# %%
kd = KernelDensity(bandwidth=0.025, kernel='tophat')

kd.fit(coords,)

sample = kd.sample(10000)

# %%
r = osrm.table(sample)

# %%
with open('val_10k.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %%
del r

# %%
gc.collect()
# Out:
# 40

# %% [markdown]
# ## Тест

# %%
coords_test = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[:, 8].to_list())))

# %%
rand_ind = np.random.choice(np.arange(len(coords_test)), size=(10000,), replace=False)

# %%
test = coords_test[rand_ind]

# %%
r = osrm.table(test)

# %%
with open('test_10k.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# ## Москва

# %% [markdown]
# Треин

# %%
num_p = 10000
theta = np.pi*np.random.rand(num_p)
r = 0.18*np.sqrt(np.random.rand(num_p))

m_coords = np.abs(np.array((r*np.cos(theta), r*np.sin(theta))) - np.array((37.62459, 55.74990)).reshape(2, -1)).T

# %%
r = osrm.table(m_coords)

# %%
with open('moscow_train_10k.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# Валидация

# %%
num_p = 10000
theta = np.pi*np.random.rand(num_p)
r = 0.18*np.sqrt(np.random.rand(num_p))

m_coords = np.abs(np.array((r*np.cos(theta), r*np.sin(theta))) - np.array((37.62459, 55.74990)).reshape(2, -1)).T

# %%
r = osrm.table(m_coords)

# %%
with open('moscow_val_10k.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# Тест

# %%
num_p = 10000
theta = np.pi*np.random.rand(num_p)
r = 0.18*np.sqrt(np.random.rand(num_p))

m_coords = np.abs(np.array((r*np.cos(theta), r*np.sin(theta))) - np.array((37.62459, 55.74990)).reshape(2, -1)).T

# %%
r = osrm.table(m_coords)

# %%
with open('moscow_test_10k.pkl', 'wb') as f:
    pickle.dump((r[0]/60, r[1]), f)

# %% [markdown]
# ## Датасет для проблемы размером 500

# %%
dataset_size = 100
problem_size = 500
num_vehicles = 50
list_id = ['name' + str(i) for i in range(problem_size + 2)]

# %%
df_cut.drop('OrderID', axis=1, inplace=True)

# %%
# %%time

dataset = []
for i in range(dataset_size):
    data = {}
    rand_ind = np.random.choice(df_cut.shape[0], size=(problem_size), replace=False)
    data['demands'] = np.concatenate((np.array([0]), df_cut.iloc[rand_ind, 0].to_numpy().squeeze(), np.array([0])))
    data['coords'] = np.array(list(map(lambda x: (float(x.split(', ')[1][:-1]),
                    float(x.split(', ')[0][1:])), df_cut.iloc[rand_ind, 7].to_list())))
    data['coords'] = np.concatenate((depot, data['coords'], depot))
    data['num_vehicles'] = num_vehicles
    data['vehicle_capacities'] = [700]*data['num_vehicles']
    t = np.random.choice([0, 120, 240, 360, 480, 600], size=(problem_size + 2))
    t1 = t + 120
    data['time_windows'] = np.concatenate((t.reshape(-1, 1), t1.reshape(-1, 1)), axis=1)
    data['time_windows'][[0, problem_size+1], 0] = 0
    data['time_windows'][0, 1] = 150
    data['time_windows'][ problem_size+1, 1] = 720
    r = osrm.table(data['coords'], ids_origin=list_id, output='dataframe')
    lon = (data['coords'][:, 0] - data['coords'][:, 0].min()).reshape(-1, 1)
    lat = (data['coords'][:, 1] - data['coords'][:, 1].min()).reshape(-1, 1)
    data['coords'] = np.concatenate((lon/lon.max(), lat/lat.max()), axis=1)
    data['time_matrix'] = (r[0]/60).to_numpy()
    data['time_matrix'] += 15
    data['time_matrix'] -= np.diag([15]*(problem_size+2))
    data['time_matrix'][:, -1] = 0
    data['time_matrix'][-1, :] = 0
    dataset.append(data)
# Out:
# Wall time: 5min 16s

# %%
with open('cvrp_tw_500_dataset.pkl', 'wb') as f:
    pickle.dump(dataset, f)

# %% [markdown]
# ## Датасет треин и тест для Москвы

# %% [markdown]
# ### Train

# %%
with open('moscow_train_10k.pkl', 'rb') as f:
    r = pickle.load(f)

locs = r[1]

del r

dataset_size = 100
problem_size = 100
num_vehicles = 50
list_id = ['name' + str(i) for i in range(problem_size + 2)]

locs = np.array(locs)

# %%
# %%time


dataset = []
for i in tqdm(range(dataset_size)):
    data = {}
    rand_ind = np.random.choice(len(locs), size=(problem_size+2), replace=False)
    data['demands'] = torch.as_tensor(np.random.choice(np.arange(1, 101), size=(problem_size + 2)),
                              dtype=torch.float)
    data['coords'] = locs[rand_ind]
    data['num_vehicles'] = num_vehicles
    data['vehicle_capacities'] = [700]*data['num_vehicles']
    t = np.random.choice([0, 120, 240, 360, 480, 600], size=(problem_size + 2))
    t1 = t + 120
    data['time_windows'] = np.concatenate((t.reshape(-1, 1), t1.reshape(-1, 1)), axis=1)
    data['time_windows'][[0, problem_size+1], 0] = 0
    data['time_windows'][0, 1] = 150
    data['time_windows'][ problem_size+1, 1] = 720
    r = osrm.table(data['coords'], ids_origin=list_id, output='dataframe')
    lon = (data['coords'][:, 0] - data['coords'][:, 0].min()).reshape(-1, 1)
    lat = (data['coords'][:, 1] - data['coords'][:, 1].min()).reshape(-1, 1)
    data['coords'] = np.concatenate((lon/lon.max(), lat/lat.max()), axis=1)
    data['time_matrix'] = (r[0]/60).to_numpy()
    data['time_matrix'] += 15
    data['time_matrix'] -= np.diag([15]*(problem_size+2))
    data['time_matrix'][:, -1] = 0
    data['time_matrix'][-1, :] = 0
    dataset.append(data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:38<00:00,  2.18s/it]
# Wall time: 3min 38s

# %%
with open('cvrp_tw_dataset_moscow_train.pkl', 'wb') as f:
    pickle.dump(dataset, f)

# %% [markdown]
# ### Test

# %%
with open('moscow_test_10k.pkl', 'rb') as f:
    r = pickle.load(f)

locs = r[1]

del r

dataset_size = 100
problem_size = 100
num_vehicles = 50
list_id = ['name' + str(i) for i in range(problem_size + 2)]

locs = np.array(locs)

# %%
# %%time


dataset = []
for i in tqdm(range(dataset_size)):
    data = {}
    rand_ind = np.random.choice(len(locs), size=(problem_size+2), replace=False)
    data['demands'] = torch.as_tensor(np.random.choice(np.arange(1, 101), size=(problem_size + 2)),
                              dtype=torch.float)
    data['coords'] = locs[rand_ind]
    data['num_vehicles'] = num_vehicles
    data['vehicle_capacities'] = [700]*data['num_vehicles']
    t = np.random.choice([0, 120, 240, 360, 480, 600], size=(problem_size + 2))
    t1 = t + 120
    data['time_windows'] = np.concatenate((t.reshape(-1, 1), t1.reshape(-1, 1)), axis=1)
    data['time_windows'][[0, problem_size+1], 0] = 0
    data['time_windows'][0, 1] = 150
    data['time_windows'][ problem_size+1, 1] = 720
    r = osrm.table(data['coords'], ids_origin=list_id, output='dataframe')
    lon = (data['coords'][:, 0] - data['coords'][:, 0].min()).reshape(-1, 1)
    lat = (data['coords'][:, 1] - data['coords'][:, 1].min()).reshape(-1, 1)
    data['coords'] = np.concatenate((lon/lon.max(), lat/lat.max()), axis=1)
    data['time_matrix'] = (r[0]/60).to_numpy()
    data['time_matrix'] += 15
    data['time_matrix'] -= np.diag([15]*(problem_size+2))
    data['time_matrix'][:, -1] = 0
    data['time_matrix'][-1, :] = 0
    dataset.append(data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:36<00:00,  2.17s/it]
# Wall time: 3min 36s

# %%
with open('cvrp_tw_dataset_moscow_test.pkl', 'wb') as f:
    pickle.dump(dataset, f)

# %% [markdown]
# ## Датасет треин для Алматы

# %%
with open('loc_distance_islands.pkl', 'rb') as f:
    r = pickle.load(f)

locs = r[1]

del r

dataset_size = 100
problem_size = 100
num_vehicles = 50
list_id = ['name' + str(i) for i in range(problem_size + 2)]

locs = np.array(locs)

# %%
# %%time


dataset = []
for i in tqdm(range(dataset_size)):
    data = {}
    rand_ind = np.random.choice(len(locs), size=(problem_size+2), replace=False)
    data['demands'] = torch.as_tensor(np.random.choice(np.arange(1, 101), size=(problem_size + 2)),
                              dtype=torch.float)
    data['coords'] = locs[rand_ind]
    data['num_vehicles'] = num_vehicles
    data['vehicle_capacities'] = [700]*data['num_vehicles']
    t = np.random.choice([0, 120, 240, 360, 480, 600], size=(problem_size + 2))
    t1 = t + 120
    data['time_windows'] = np.concatenate((t.reshape(-1, 1), t1.reshape(-1, 1)), axis=1)
    data['time_windows'][[0, problem_size+1], 0] = 0
    data['time_windows'][0, 1] = 150
    data['time_windows'][ problem_size+1, 1] = 720
    r = osrm.table(data['coords'], ids_origin=list_id, output='dataframe')
    lon = (data['coords'][:, 0] - data['coords'][:, 0].min()).reshape(-1, 1)
    lat = (data['coords'][:, 1] - data['coords'][:, 1].min()).reshape(-1, 1)
    data['coords'] = np.concatenate((lon/lon.max(), lat/lat.max()), axis=1)
    data['time_matrix'] = (r[0]/60).to_numpy()
    data['time_matrix'] += 15
    data['time_matrix'] -= np.diag([15]*(problem_size+2))
    data['time_matrix'][:, -1] = 0
    data['time_matrix'][-1, :] = 0
    dataset.append(data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:35<00:00,  2.15s/it]
# Wall time: 3min 35s

# %%
with open('cvrp_tw_dataset_big_islands_train.pkl', 'wb') as f:
    pickle.dump(dataset, f)
